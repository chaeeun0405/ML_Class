# %% [markdown]
# <a href="https://colab.research.google.com/github/chaeeun0405/ML_Class/blob/main/3%EC%A3%BC%EC%B0%A8/ML_3-2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -----------------------------
# 1) 데이터 준비
# -----------------------------

import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/dataset/weather.csv", header=0).dropna()
df
# Out:
#            Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1     11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2     11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3     11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4     11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
# ..          ...       ...      ...      ...       ...          ...       ...
# 361  10/27/2008  Canberra      9.0     30.7       0.0          7.6      12.1
# 362  10/28/2008  Canberra      7.1     28.4       0.0         11.6      12.7
# 363  10/29/2008  Canberra     12.5     19.9       0.0          8.4       5.3
# 364  10/30/2008  Canberra     12.5     26.9       0.0          5.0       7.1
# 365  10/31/2008  Canberra     12.3     30.2       0.0          6.0      12.6
#
# ...

# %%
# 결측치 확인
df.isnull().sum()
# Out:
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RISK_MM          0
# RainTomorrow     0
# dtype: int64

# %%
# 결측치 제거
df = df.dropna()
df.isnull().sum()
# Out:
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RISK_MM          0
# RainTomorrow     0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %%
# 모든 레이블을 숫자로 변형

from sklearn.preprocessing import LabelEncoder

label_encoders = {}
for column in df.columns:
    label_encoders[column] = LabelEncoder()
    df[column] = label_encoders[column].fit_transform(df[column])

df
# Out:
#      Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0      59         0       90      111         0           15        43
# 1      70         0      138      130        16           20        75
# 2      81         0      135      106        16           27        24
# 3      83         0      133       42        43           34        69
# 4      84         0       86       46        13           26        84
# ..    ...       ...      ...      ...       ...          ...       ...
# 361    47         0      100      152         0           36        99
# 362    48         0       81      141         0           51       104
# 363    49         0      125       78         0           40        36
# 364    51         0      125      130         0           23        50
# 365    52         0      123      150         0           28       103
#
#      WindGustDir  WindGustSpeed  WindDir9am  ...  Humidity3pm  Pressure9am  \
# ...

# %%
y = df['RainTomorrow']
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    0
# Name: RainTomorrow, dtype: int64

# %%
X = df.drop('RainTomorrow',axis=1)
X.head()
# Out:
#    Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0    59         0       90      111         0           15        43
# 1    70         0      138      130        16           20        75
# 2    81         0      135      106        16           27        24
# 3    83         0      133       42        43           34        69
# 4    84         0       86       46        13           26        84
#
#    WindGustDir  WindGustSpeed  WindDir9am  ...  Humidity9am  Humidity3pm  \
# 0            7              8          12  ...           29           15
# 1            1             12           0  ...           41           22
# 2            7             33           3  ...           43           55
# 3            7             20          14  ...           23           42
# 4           10             18          10  ...           29           35
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test=train_test_split(X,
                                                  y,
                                                  test_size=0.2,
                                                  shuffle=True,
                                                  random_state=12)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (262, 23) (262,)
# (66, 23) (66,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

model = LinearRegression()         # 모델 구성
model.fit(X_train, y_train)        # 모델 훈련
ly_preds = model.predict(X_test)   # 예측데이터 생성
print(mean_squared_error(y_test, ly_preds))  #평가
# Out:
# 0.04335056615310828

# %%
# 예측값과 실제 값 차이를 산접도로 표시, 노란색 예측

import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.scatter(X_test['Rainfall'], y_test, label='y_test')
plt.scatter(X_test['Rainfall'], ly_preds, c='y', label='ly_preds')
#plt.plot(X_train, lr.predict(X_train), color='blue')
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor()
model.fit(X_train, y_train)

from sklearn.metrics import mean_squared_error

ry_preds = model.predict(X_test)
print('평균제곱근오차', mean_squared_error(ry_preds, y_test))
# Out:
# 평균제곱근오차 0.0037121212121212117

# %%
plt.figure(figsize=(10,5))
plt.scatter(X_test['Rainfall'], y_test, label='y_test')
plt.scatter(X_test['Rainfall'], ry_preds, c='orange', label='ry_preds')

plt.show()

# %%
from sklearn.tree import DecisionTreeRegressor

model = DecisionTreeRegressor()
model.fit(X_train, y_train)

from sklearn.metrics import mean_squared_error

dy_preds = model.predict(X_test)
print('평균제곱근오차', mean_squared_error(dy_preds, y_test))
# Out:
# 평균제곱근오차 0.0

# %%
plt.figure(figsize=(10,5))
plt.scatter(X_test['Rainfall'], y_test, label='y_test')
plt.scatter(X_test['Rainfall'], dy_preds, c='g', label='dy_preds')
plt.show()
