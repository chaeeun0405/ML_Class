# %% [markdown]
# <a href="https://colab.research.google.com/github/chaeeun0405/ML_Class/blob/main/4%EC%A3%BC%EC%B0%A8/ML_4%EC%A3%BC%EC%B0%A8_%EA%B3%BC%EC%A0%9C_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1. 와인 데이터세트로 4가지 ML(LR, DT, RF, KNN) 분류 + 기울기/절편 출력

# -----------------------------
# 1) 데이터 준비
# -----------------------------

import pandas as pd

cols = ["values", "Alcohol", "Malic acid", "Ash", "Alcalinity of ash", "Magnesium", "Total phenols", "Flavanoids", "Nonflavanoid phenols", "Proanthocyanins", "Color intensity", "Hue", "OD280/OD315 of diluted wines", "Proline" ]
df = pd.read_csv("/content/drive/MyDrive/dataset/wine.data", header=0, names=cols).dropna()
df
# Out:
#      values  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0         1    13.20        1.78  2.14               11.2        100
# 1         1    13.16        2.36  2.67               18.6        101
# 2         1    14.37        1.95  2.50               16.8        113
# 3         1    13.24        2.59  2.87               21.0        118
# 4         1    14.20        1.76  2.45               15.2        112
# ..      ...      ...         ...   ...                ...        ...
# 172       3    13.71        5.65  2.45               20.5         95
# 173       3    13.40        3.91  2.48               23.0        102
# 174       3    13.27        4.28  2.26               20.0        120
# 175       3    13.17        2.59  2.37               20.0        120
# 176       3    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# ...

# %%
# 결측치 확인
df.isnull().sum()
# Out:
# values                          0
# Alcohol                         0
# Malic acid                      0
# Ash                             0
# Alcalinity of ash               0
# Magnesium                       0
# Total phenols                   0
# Flavanoids                      0
# Nonflavanoid phenols            0
# Proanthocyanins                 0
# Color intensity                 0
# Hue                             0
# OD280/OD315 of diluted wines    0
# Proline                         0
# dtype: int64

# %%
# 결측치 제거
df = df.dropna()
df.isnull().sum()
# Out:
# values                          0
# Alcohol                         0
# Malic acid                      0
# Ash                             0
# Alcalinity of ash               0
# Magnesium                       0
# Total phenols                   0
# Flavanoids                      0
# Nonflavanoid phenols            0
# Proanthocyanins                 0
# Color intensity                 0
# Hue                             0
# OD280/OD315 of diluted wines    0
# Proline                         0
# dtype: int64

# %%
# 입력과 출력 분리

X = df.drop(columns=["values"])
y = df["values"]

X # 분리 후 확인
# Out:
#      Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 0      13.20        1.78  2.14               11.2        100           2.65
# 1      13.16        2.36  2.67               18.6        101           2.80
# 2      14.37        1.95  2.50               16.8        113           3.85
# 3      13.24        2.59  2.87               21.0        118           2.80
# 4      14.20        1.76  2.45               15.2        112           3.27
# ..       ...         ...   ...                ...        ...            ...
# 172    13.71        5.65  2.45               20.5         95           1.68
# 173    13.40        3.91  2.48               23.0        102           1.80
# 174    13.27        4.28  2.26               20.0        120           1.59
# 175    13.17        2.59  2.37               20.0        120           1.65
# 176    14.13        4.10  2.74               24.5         96           2.05
#
# ...

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 172    3
# 173    3
# 174    3
# 175    3
# 176    3
# Name: values, Length: 177, dtype: int64

# %%
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# 훈련과 테스트 데이터 분리
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# 각 데이터의 shape 확인 (전체데이터 수, 컬럼숫자)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((141, 13), (36, 13), (141,), (36,))

# %%
from sklearn.preprocessing import StandardScaler

# StandardScaler 객체 생성
scaler = StandardScaler()

# 학습 데이터(X_train)를 스케일링
# fit()으로 평균과 표준편차를 계산하고, transform()으로 변환
X_train_scaled = scaler.fit_transform(X_train)

# 테스트 데이터(X_test)를 스케일링
# X_train에서 계산된 평균과 표준편차를 그대로 사용해 변환
X_test_scaled = scaler.transform(X_test)

# %%
# -----------------------------
# 2) 모델 구성
# -----------------------------
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

dt = DecisionTreeClassifier(random_state=42)
rf = RandomForestClassifier(n_estimators=200, random_state=42)
lr = LogisticRegression(max_iter=500)


# -----------------------------
# 3) 스케일링된 데이터를 사용하여 모델 학습
# -----------------------------

dt.fit(X_train_scaled, y_train)
rf.fit(X_train_scaled, y_train)
lr.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(max_iter=500)

# %%
# -----------------------------
# 4) 예측결과 생성
# -----------------------------


dt_y_pred = dt.predict(X_test)
rf_y_pred = rf.predict(X_test)
lr_y_pred = lr.predict(X_test)

# 정답값 출력

y_test
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# 10     1
# 133    3
# 28     1
# 120    2
# 61     2
# 51     1
# 7      1
# 65     2
# 128    2
# 165    3
# 101    2
# 142    3
# 42     1
# 129    3
# 14     1
# 107    2
# 104    2
# 20     1
# 99     2
# 38     1
# 92     2
# 59     2
# 22     1
# 18     1
# 97     2
# 63     2
# 57     1
# 131    3
# 111    2
# 154    3
# 47     1
# 175    3
# 93     2
# 176    3
# 163    3
# 172    3
# Name: values, dtype: int64

# %%
# -----------------------------
# 5) 예측결과와 정답을 비교한 정확도 평가
# -----------------------------

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

dt_acc = accuracy_score(y_test, dt_y_pred)
rf_acc = accuracy_score(y_test, rf_y_pred )
lr_acc = accuracy_score(y_test, lr_y_pred)


print("=== DT Test Accuracy ===")
print(f"Decision Tree : {dt_acc:.4f}")
print (confusion_matrix(y_test,dt_y_pred))

print("=== RF Test Accuracy ===")
print(f"Random Forest : {rf_acc:.4f}")
print (confusion_matrix(y_test,rf_y_pred))

print("=== LR Test Accuracy ===")
print(f"Logistic Reg. : {lr_acc:.4f}")
print (confusion_matrix(y_test,lr_y_pred))
# Out:
# === DT Test Accuracy ===
# Decision Tree : 0.3333
# [[12  0  0]
#  [14  0  0]
#  [10  0  0]]
# === RF Test Accuracy ===
# Random Forest : 0.3333
# [[12  0  0]
#  [14  0  0]
#  [10  0  0]]
# === LR Test Accuracy ===
# Logistic Reg. : 0.3333
# [[12  0  0]
#  [14  0  0]
#  [10  0  0]]

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)   # 이미 2차원 배열이라 reshape 필요 없음

print("훈련 세트 점수:", knn.score(X_train, y_train))
print("테스트 세트 점수:", knn.score(X_test, y_test))
# Out:
# 훈련 세트 점수: 0.8581560283687943
# 테스트 세트 점수: 0.6666666666666666

# %%
#2. 와인 데이터세트로 딥러닝 분류 (FC만 이용)


# 1) 스케일링
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# 2) 원핫 인코딩
Y = pd.get_dummies(y).values

# %%
# 3) train/test 분리
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, Y, test_size=0.2, random_state=0
)

# %%
# 4) 모델 구성
model = models.Sequential([
    layers.Dense(64, activation="relu", input_shape=(X_train.shape[1],)),
    layers.Dense(32, activation="relu"),
    layers.Dense(Y.shape[1], activation="softmax")
])

model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# 5) 학습
history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=50,
    batch_size=16,
    verbose=1
)
# Out:
# Epoch 1/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.3834 - loss: 1.0579 - val_accuracy: 0.6207 - val_loss: 0.9032
# Epoch 2/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7924 - loss: 0.8151 - val_accuracy: 0.7241 - val_loss: 0.7440
# Epoch 3/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8895 - loss: 0.6311 - val_accuracy: 0.8276 - val_loss: 0.6211
# Epoch 4/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9683 - loss: 0.4741 - val_accuracy: 0.8276 - val_loss: 0.5239
# Epoch 5/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9074 - loss: 0.4205 - val_accuracy: 0.8276 - val_loss: 0.4485
# Epoch 6/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9616 - loss: 0.3150 - val_accuracy: 0.8621 - val_loss: 0.3840
# Epoch 7/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9406 - loss: 0.2700 - val_accuracy: 0.8621 - val_loss: 0.3325
# Epoch 8/50
# ...

# %%
# 6) 예측
y_pred = model.predict(X_test)
y_test_class = np.argmax(y_test, axis=1)
y_pred_class = np.argmax(y_pred, axis=1)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step

# %%
# 7) 학습곡선 시각화
loss = history.history['loss']
val_loss = history.history['val_loss']
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# 8) 결과 출력
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(y_test_class, y_pred_class))
print(confusion_matrix(y_test_class, y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       1.00      1.00      1.00        15
#            2       1.00      1.00      1.00         7
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36
#
# [[14  0  0]
#  [ 0 15  0]
#  [ 0  0  7]]

# %%
#3. 유방암 데이터로 딥러닝 분류 (FC만 이용)

# -----------------------------
# 1) 데이터 준비
# -----------------------------

df = pd.read_csv("/content/drive/MyDrive/dataset/breast_cancer.csv").dropna()

# %%
# 결측치 확인
df.isnull().sum()
# Out:
# Unnamed: 0                 0
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# label                      0
# ...

# %%
# 결측치 제거
df = df.dropna()
df.isnull().sum()
# Out:
# Unnamed: 0                 0
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# label                      0
# ...

# %%
# 입력과 출력 분리

X = df.drop(columns=["label"])
y = df["label"]

X # 분리 후 확인
# Out:
#      Unnamed: 0  mean radius  mean texture  mean perimeter  mean area  \
# 0             0        17.99         10.38          122.80     1001.0
# 1             1        20.57         17.77          132.90     1326.0
# 2             2        19.69         21.25          130.00     1203.0
# 3             3        11.42         20.38           77.58      386.1
# 4             4        20.29         14.34          135.10     1297.0
# ..          ...          ...           ...             ...        ...
# 564         564        21.56         22.39          142.00     1479.0
# 565         565        20.13         28.25          131.20     1261.0
# 566         566        16.60         28.08          108.30      858.1
# 567         567        20.60         29.33          140.10     1265.0
# 568         568         7.76         24.54           47.92      181.0
#
#      mean smoothness  mean compactness  mean concavity  mean concave points  \
# ...

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 564    0
# 565    0
# 566    0
# 567    0
# 568    1
# Name: label, Length: 569, dtype: int64

# %%
from tensorflow.keras import layers, models
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 1) 스케일링
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# 2) 원핫 인코딩
Y = pd.get_dummies(y).values
#X = X.values

# %%
# 3) train/test 분리
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, Y, test_size=0.2, random_state=0
)

# %%
# 4) 모델 구성
model = models.Sequential([
    layers.Dense(64, activation="relu", input_shape=(X_train.shape[1],)),
    layers.Dense(32, activation="relu"),
    layers.Dense(Y.shape[1], activation="softmax")
])

model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# 5) 학습
history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=50,
    batch_size=16,
    verbose=1
)
# Out:
# Epoch 1/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.6808 - loss: 0.6037 - val_accuracy: 0.9560 - val_loss: 0.2842
# Epoch 2/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9493 - loss: 0.2375 - val_accuracy: 0.9780 - val_loss: 0.1552
# Epoch 3/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9778 - loss: 0.1263 - val_accuracy: 0.9890 - val_loss: 0.1028
# Epoch 4/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9640 - loss: 0.1007 - val_accuracy: 0.9890 - val_loss: 0.0783
# Epoch 5/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9787 - loss: 0.0859 - val_accuracy: 0.9890 - val_loss: 0.0631
# Epoch 6/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9829 - loss: 0.0670 - val_accuracy: 0.9890 - val_loss: 0.0525
# Epoch 7/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9872 - loss: 0.0585 - val_accuracy: 0.9890 - val_loss: 0.0459
# Epoch 8/50
# ...

# %%
# 6) 예측
y_pred = model.predict(X_test)
y_test_class = np.argmax(y_test, axis=1)
y_pred_class = np.argmax(y_pred, axis=1)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step

# %%
# 7) 학습곡선 시각화
loss = history.history['loss']
val_loss = history.history['val_loss']
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# 8) 결과 출력
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(y_test_class, y_pred_class))
print(confusion_matrix(y_test_class, y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96        47
#            1       0.97      0.97      0.97        67
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.96      0.96       114
# weighted avg       0.96      0.96      0.96       114
#
# [[45  2]
#  [ 2 65]]
