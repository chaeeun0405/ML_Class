# %% [markdown]
# <a href="https://colab.research.google.com/github/chaeeun0405/ML_Class/blob/main/4%EC%A3%BC%EC%B0%A8/ML_4-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -----------------------------
# 1) 데이터 준비
# -----------------------------

import pandas as pd

cols = ["values", "Alcohol", "Malic acid", "Ash", "Alcalinity of ash", "Magnesium", "Total phenols", "Flavanoids", "Nonflavanoid phenols", "Proanthocyanins", "Color intensity", "Hue", "OD280/OD315 of diluted wines", "Proline" ]
df = pd.read_csv("/content/drive/MyDrive/dataset/wine.data", header=0, names=cols).dropna()
df
# Out:
#      values  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0         1    13.20        1.78  2.14               11.2        100
# 1         1    13.16        2.36  2.67               18.6        101
# 2         1    14.37        1.95  2.50               16.8        113
# 3         1    13.24        2.59  2.87               21.0        118
# 4         1    14.20        1.76  2.45               15.2        112
# ..      ...      ...         ...   ...                ...        ...
# 172       3    13.71        5.65  2.45               20.5         95
# 173       3    13.40        3.91  2.48               23.0        102
# 174       3    13.27        4.28  2.26               20.0        120
# 175       3    13.17        2.59  2.37               20.0        120
# 176       3    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# ...

# %%
# 결측치 확인
df.isnull().sum()
# Out:
# values                          0
# Alcohol                         0
# Malic acid                      0
# Ash                             0
# Alcalinity of ash               0
# Magnesium                       0
# Total phenols                   0
# Flavanoids                      0
# Nonflavanoid phenols            0
# Proanthocyanins                 0
# Color intensity                 0
# Hue                             0
# OD280/OD315 of diluted wines    0
# Proline                         0
# dtype: int64

# %%
# 결측치 제거
df = df.dropna()
df.isnull().sum()
# Out:
# values                          0
# Alcohol                         0
# Malic acid                      0
# Ash                             0
# Alcalinity of ash               0
# Magnesium                       0
# Total phenols                   0
# Flavanoids                      0
# Nonflavanoid phenols            0
# Proanthocyanins                 0
# Color intensity                 0
# Hue                             0
# OD280/OD315 of diluted wines    0
# Proline                         0
# dtype: int64

# %%
# 입력과 출력 분리

X = df.drop(columns=["values"])
y = df["values"]

X # 분리 후 확인
# Out:
#      Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 0      13.20        1.78  2.14               11.2        100           2.65
# 1      13.16        2.36  2.67               18.6        101           2.80
# 2      14.37        1.95  2.50               16.8        113           3.85
# 3      13.24        2.59  2.87               21.0        118           2.80
# 4      14.20        1.76  2.45               15.2        112           3.27
# ..       ...         ...   ...                ...        ...            ...
# 172    13.71        5.65  2.45               20.5         95           1.68
# 173    13.40        3.91  2.48               23.0        102           1.80
# 174    13.27        4.28  2.26               20.0        120           1.59
# 175    13.17        2.59  2.37               20.0        120           1.65
# 176    14.13        4.10  2.74               24.5         96           2.05
#
# ...

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 172    3
# 173    3
# 174    3
# 175    3
# 176    3
# Name: values, Length: 177, dtype: int64

# %%
from tensorflow.keras import layers, models
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 1) 스케일링
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# 2) 원핫 인코딩
Y = pd.get_dummies(y).values
#X = X.values

# %%
# 3) train/test 분리
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, Y, test_size=0.2, random_state=0
)

# %%
# 4) 모델 구성
model = models.Sequential([
    layers.Dense(64, activation="relu", input_shape=(X_train.shape[1],)),
    layers.Dense(32, activation="relu"),
    layers.Dense(Y.shape[1], activation="softmax")
])

model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# 5) 학습
history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=50,
    batch_size=16,
    verbose=1
)
# Out:
# Epoch 1/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.5096 - loss: 0.9734 - val_accuracy: 0.5517 - val_loss: 0.8810
# Epoch 2/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5808 - loss: 0.9045 - val_accuracy: 0.7241 - val_loss: 0.7649
# Epoch 3/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8020 - loss: 0.6546 - val_accuracy: 0.8276 - val_loss: 0.6706
# Epoch 4/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8073 - loss: 0.6411 - val_accuracy: 0.8966 - val_loss: 0.5847
# Epoch 5/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9427 - loss: 0.5313 - val_accuracy: 0.9310 - val_loss: 0.5123
# Epoch 6/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9116 - loss: 0.4933 - val_accuracy: 0.9310 - val_loss: 0.4410
# Epoch 7/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9487 - loss: 0.3699 - val_accuracy: 0.9310 - val_loss: 0.3847
# Epoch 8/50
# ...

# %%
# 6) 예측
y_pred = model.predict(X_test)
y_test_class = np.argmax(y_test, axis=1)
y_pred_class = np.argmax(y_pred, axis=1)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step

# %%
# 7) 학습곡선 시각화
loss = history.history['loss']
val_loss = history.history['val_loss']
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# 8) 결과 출력
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(y_test_class, y_pred_class))
print(confusion_matrix(y_test_class, y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       0.94      1.00      0.97        15
#            2       1.00      0.86      0.92         7
#
#     accuracy                           0.97        36
#    macro avg       0.98      0.95      0.96        36
# weighted avg       0.97      0.97      0.97        36
#
# [[14  0  0]
#  [ 0 15  0]
#  [ 0  1  6]]
